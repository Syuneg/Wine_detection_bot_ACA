# %%
import os, json, random, math, glob, re, shutil
import pandas as pd
from PIL import Image

# %% [markdown]
# ### Clear csv and make them jsons

# %%
df = pd.read_csv(r'C:\Users\syune\OneDrive\Desktop\Wine_Data/new_labels.csv')
df = df.fillna('')

# %%
df = df[["WineID", 'WineName', 'Type', 'Country', 'WineryName']]
df
# Out:
#       WineID                                    WineName       Type  \
# 0     100001                          Espumante Moscatel  Sparkling
# 1     100002                                  Ancellotta        Red
# 2     100003                          Cabernet Sauvignon        Red
# 3     100005             Maison de Ville Cabernet-Merlot        Red
# 4     100007                Do Lugar Moscatel Espumantes  Sparkling
# ...      ...                                         ...        ...
# 1002  199408                               Petite Arvine      White
# 1003  199481                         St. Laurent Reserve        Red
# 1004  199533                     Mariengarten Chardonnay      White
# 1005  199885  Grüner Veltliner Federspiel Ried Kreuzberg      White
# 1006  200139                            Drama Queen Rosé       Rosé
#
#           Country           WineryName
# 0          Brazil          Casa Perini
# 1          Brazil          Casa Perini
# 2          Brazil         Castellamare
# 3          Brazil               Aurora
# 4          Brazil           Dal Pizzol
# ...           ...                  ...
# 1002  Switzerland      Niklaus Wittwer
# 1003      Austria          Hundsdorfer
# 1004      Austria       Muster-Gamlitz
# 1005      Austria        Josef Fischer
# 1006  New Zealand  Bridge Pa Vineyards
#
# [1007 rows x 5 columns]

# %%
unique_names = df["Type"].unique()
unique_names
# Out:
# array(['Sparkling', 'Red', 'White', 'Dessert/Port', 'Dessert', 'Rosé'],
#       dtype=object)

# %%
df["Type"] = df["Type"].replace({"Dessert/Port": "Dessert", "Rosé": "Rose"})

# %%
df = df.rename(columns={"WineName": "Name", "WineryName": "Brand", "Country": "Region"})

# %%
df.to_excel(r'C:\Users\syune\OneDrive\Desktop\Wine_Data/new_labels.xlsx')

# %%
output_json_dir = r'C:\Users\syune\OneDrive\Desktop\Wine_Data/new_dataset/labels'

# %%
for index, row in df.iterrows():
    image_id = str(row['WineID'])  # convert int to string
    image_name = image_id + ".jpg"
    # Write JSON
    data = {
        "Name": row.get("Name", ""),
        "Brand": row.get("Brand", ""),
        "Type": row.get("Type", ""),
        "Region": row.get("Region", "")
    }
    json_filename = image_id + ".json"
    json_path = os.path.join(output_json_dir, json_filename)
    with open(json_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
## Change names to avoid overlaps
def rename_and_move_files(image_folder, json_folder, output_image_folder, output_json_folder, offset=17000000):
    os.makedirs(output_image_folder, exist_ok=True)
    os.makedirs(output_json_folder, exist_ok=True)
    for filename in os.listdir(image_folder):
        match = re.match(r"(\d+)\.jpeg", filename)
        if match:
            old_number = int(match.group(1))
            new_number = old_number + offset
            new_name = f"{new_number}.jpeg"
            # Copy and rename image
            src_image = os.path.join(image_folder, filename)
            dst_image = os.path.join(output_image_folder, new_name)
            shutil.copyfile(src_image, dst_image)
            # Copy and rename JSON (if exists)
            old_json = os.path.join(json_folder, f"{old_number}.json")
            new_json = os.path.join(output_json_folder, f"{new_number}.json")
            if os.path.exists(old_json):
                shutil.copyfile(old_json, new_json)
# Run the function
rename_and_move_files(
    image_folder = r'C:\Users\syune\OneDrive\Desktop\Wine_Data/new_dataset/images',
    json_folder = r'C:\Users\syune\OneDrive\Desktop\Wine_Data/new_dataset/labels',
    output_image_folder = r'C:\Users\syune\OneDrive\Desktop\Wine_Data/cleaned_dataset/images', 
    output_json_folder = r'C:\Users\syune\OneDrive\Desktop\Wine_Data/cleaned_dataset/labels',
    offset=17000000
)

# %% [markdown]
# ### Group data to folders

# %%
labels_dir = r"C:\Users\syune\OneDrive\Desktop/Wine_Data/cleaned_dataset/labels"   # folder with JSON files
images_dir = r"C:\Users\syune\OneDrive\Desktop/Wine_Data/cleaned_dataset/images"   # folder with images
output_base = r"C:\Users\syune\OneDrive\Desktop\Wine_Data/Data"

# Make sure output folders exist
os.makedirs(output_base, exist_ok=True)
# Loop over all JSON label files
for json_file in os.listdir(labels_dir):
    if json_file.lower().endswith(".json"):
        json_path = os.path.join(labels_dir, json_file)
        # Read JSON file
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        # Get the wine type
        wine_type = data.get("Type", "Unknown").strip()
        
        # Normalize folder name
        type_folder_name = wine_type.lower().replace(" ", "_")
        # Create destination folders
        labels_dest_dir = os.path.join(output_base, f"{type_folder_name}/labels")
        images_dest_dir = os.path.join(output_base, f"{type_folder_name}/images")
        os.makedirs(labels_dest_dir, exist_ok=True)
        os.makedirs(images_dest_dir, exist_ok=True)
        # Move JSON
        shutil.move(json_path, os.path.join(labels_dest_dir, json_file))
        # Move corresponding image (assuming same filename but different extension)
        image_name_base = os.path.splitext(json_file)[0]
        for ext in [".jpg", ".jpeg", ".png", ".webp"]:
            image_path = os.path.join(images_dir, image_name_base + ext)
            if os.path.exists(image_path):
                shutil.move(image_path, os.path.join(images_dest_dir, image_name_base + ext))
                break

# %% [markdown]
# ### Clean Data

# %%
base_dir = r"C:\Users\syune\OneDrive\Desktop\Wine_Data/Data"

# get all folder names inside Data
folders = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]

# now build full image/json dirs
image_dirs = [os.path.join(base_dir, f, "images") for f in folders]
json_dirs = [os.path.join(base_dir, f, "jsons") for f in folders]

# Example: loop through each image folder
for image_dir in image_dirs:
    for img_name in os.listdir(image_dir):
        img_path = os.path.join(image_dir, img_name)
        if os.path.getsize(img_path) < 7 * 1024:  # remove files smaller than 7 KB
            os.remove(img_path)

# %%
folders = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]

for folder in folders:
    images_dir = os.path.join(base_dir, folder, "images")
    jsons_dir = os.path.join(base_dir, folder, "labels")

    if not os.path.exists(images_dir) or not os.path.exists(jsons_dir):
        continue

    for json_file in os.listdir(jsons_dir):
        base_name = os.path.splitext(json_file)[0]

        possible_images = [base_name + ext for ext in ['.jpg', '.jpeg', '.JPG', '.JPEG', '.png']]

        image_exists = any(os.path.exists(os.path.join(images_dir, img)) for img in possible_images)

        print(f"[{folder}] Checking JSON: {json_file} -> Image exists? {image_exists}")

        if not image_exists:
            # os.remove(os.path.join(jsons_dir, json_file))
            print(f"[{folder}] Removed JSON without image: {json_file}")
# Out:
# [Champagne] Checking JSON: 100503.json -> Image exists? True
# [Champagne] Checking JSON: 106583.json -> Image exists? False
# [Champagne] Removed JSON without image: 106583.json
# [Champagne] Checking JSON: 111294.json -> Image exists? True
# [Champagne] Checking JSON: 12619.json -> Image exists? True
# [Champagne] Checking JSON: 135798.json -> Image exists? True
# [Champagne] Checking JSON: 13824.json -> Image exists? True
# [Champagne] Checking JSON: 145169.json -> Image exists? True
# [Champagne] Checking JSON: 14636.json -> Image exists? True
# [Champagne] Checking JSON: 14641.json -> Image exists? True
# [Champagne] Checking JSON: 14846.json -> Image exists? True
# [Champagne] Checking JSON: 155341.json -> Image exists? True
# [Champagne] Checking JSON: 158550.json -> Image exists? True
# [Champagne] Checking JSON: 162883.json -> Image exists? True
# [Champagne] Checking JSON: 167486.json -> Image exists? True
# [Champagne] Checking JSON: 173161.json -> Image exists? True
# [Champagne] Checking JSON: 17595.json -> Image exists? False
# [Champagne] Removed JSON without image: 17595.json
# [Champagne] Checking JSON: 17596.json -> Image exists? True
# [Champagne] Checking JSON: 17598.json -> Image exists? False
# [Champagne] Removed JSON without image: 17598.json
# [Champagne] Checking JSON: 17600.json -> Image exists? False
# [Champagne] Removed JSON without image: 17600.json
# [Champagne] Checking JSON: 17601.json -> Image exists? False
# [Champagne] Removed JSON without image: 17601.json
# [Champagne] Checking JSON: 179275.json -> Image exists? True
# [Champagne] Checking JSON: 18137.json -> Image exists? False
# [Champagne] Removed JSON without image: 18137.json
# [Champagne] Checking JSON: 190025.json -> Image exists? True
# [Champagne] Checking JSON: 19661.json -> Image exists? True
# [Champagne] Checking JSON: 19996.json -> Image exists? True
# [Champagne] Checking JSON: 20000.json -> Image exists? False
# [Champagne] Removed JSON without image: 20000.json
# [Champagne] Checking JSON: 20766.json -> Image exists? True
# [Champagne] Checking JSON: 21300.json -> Image exists? True
# [Champagne] Checking JSON: 21593.json -> Image exists? False
# [Champagne] Removed JSON without image: 21593.json
# [Champagne] Checking JSON: 217158.json -> Image exists? True
# [Champagne] Checking JSON: 21979.json -> Image exists? True
# [Champagne] Checking JSON: 220244.json -> Image exists? True
# [Champagne] Checking JSON: 22493.json -> Image exists? False
# [Champagne] Removed JSON without image: 22493.json
# [Champagne] Checking JSON: 22907.json -> Image exists? False
# [Champagne] Removed JSON without image: 22907.json
# [Champagne] Checking JSON: 22916.json -> Image exists? False
# [Champagne] Removed JSON without image: 22916.json
# [Champagne] Checking JSON: 22918.json -> Image exists? False
# [Champagne] Removed JSON without image: 22918.json
# [Champagne] Checking JSON: 22923.json -> Image exists? True
# [Champagne] Checking JSON: 22934.json -> Image exists? False
# [Champagne] Removed JSON without image: 22934.json
# [Champagne] Checking JSON: 239806.json -> Image exists? True
# [Champagne] Checking JSON: 25068.json -> Image exists? True
# [Champagne] Checking JSON: 25514.json -> Image exists? True
# [Champagne] Checking JSON: 25615.json -> Image exists? True
# [Champagne] Checking JSON: 25900.json -> Image exists? True
# [Champagne] Checking JSON: 25901.json -> Image exists? True
# [Champagne] Checking JSON: 25903.json -> Image exists? True
# [Champagne] Checking JSON: 26577.json -> Image exists? True
# [Champagne] Checking JSON: 267039.json -> Image exists? True
# [Champagne] Checking JSON: 268755.json -> Image exists? True
# [Champagne] Checking JSON: 268771.json -> Image exists? True
# [Champagne] Checking JSON: 279455.json -> Image exists? True
# [Champagne] Checking JSON: 280461.json -> Image exists? True
# [Champagne] Checking JSON: 28162.json -> Image exists? True
# [Champagne] Checking JSON: 28193.json -> Image exists? True
# [Champagne] Checking JSON: 28267.json -> Image exists? True
# [Champagne] Checking JSON: 28269.json -> Image exists? False
# [Champagne] Removed JSON without image: 28269.json
# [Champagne] Checking JSON: 28271.json -> Image exists? False
# [Champagne] Removed JSON without image: 28271.json
# [Champagne] Checking JSON: 28643.json -> Image exists? True
# [Champagne] Checking JSON: 29497.json -> Image exists? True
# [Champagne] Checking JSON: 29704.json -> Image exists? True
# [Champagne] Checking JSON: 29897.json -> Image exists? True
# [Champagne] Checking JSON: 299.json -> Image exists? True
# [Champagne] Checking JSON: 29949.json -> Image exists? True
# [Champagne] Checking JSON: 29950.json -> Image exists? True
# [Champagne] Checking JSON: 29951.json -> Image exists? True
# [Champagne] Checking JSON: 302363.json -> Image exists? True
# [Champagne] Checking JSON: 30240.json -> Image exists? True
# [Champagne] Checking JSON: 30241.json -> Image exists? True
# [Champagne] Checking JSON: 308056.json -> Image exists? True
# [Champagne] Checking JSON: 30945.json -> Image exists? True
# [Champagne] Checking JSON: 30970.json -> Image exists? True
# [Champagne] Checking JSON: 30971.json -> Image exists? True
# [Champagne] Checking JSON: 30974.json -> Image exists? False
# [Champagne] Removed JSON without image: 30974.json
# [Champagne] Checking JSON: 30976.json -> Image exists? True
# [Champagne] Checking JSON: 31527.json -> Image exists? True
# [Champagne] Checking JSON: 32154.json -> Image exists? True
# [Champagne] Checking JSON: 32279.json -> Image exists? True
# [Champagne] Checking JSON: 32413.json -> Image exists? True
# [Champagne] Checking JSON: 325167.json -> Image exists? True
# [Champagne] Checking JSON: 32737.json -> Image exists? True
# [Champagne] Checking JSON: 32989.json -> Image exists? True
# [Champagne] Checking JSON: 33004.json -> Image exists? True
# [Champagne] Checking JSON: 33014.json -> Image exists? True
# [Champagne] Checking JSON: 33045.json -> Image exists? True
# [Champagne] Checking JSON: 33047.json -> Image exists? True
# [Champagne] Checking JSON: 33051.json -> Image exists? False
# [Champagne] Removed JSON without image: 33051.json
# [Champagne] Checking JSON: 33053.json -> Image exists? False
# [Champagne] Removed JSON without image: 33053.json
# [Champagne] Checking JSON: 33165.json -> Image exists? True
# [Champagne] Checking JSON: 33197.json -> Image exists? True
# [Champagne] Checking JSON: 33310.json -> Image exists? True
# [Champagne] Checking JSON: 33524.json -> Image exists? False
# [Champagne] Removed JSON without image: 33524.json
# [Champagne] Checking JSON: 33955.json -> Image exists? True
# [Champagne] Checking JSON: 33979.json -> Image exists? True
# [Champagne] Checking JSON: 33980.json -> Image exists? True
# [Champagne] Checking JSON: 34094.json -> Image exists? True
# [Champagne] Checking JSON: 34451.json -> Image exists? False
# [Champagne] Removed JSON without image: 34451.json
# [Champagne] Checking JSON: 344952.json -> Image exists? True
# [Champagne] Checking JSON: 34607.json -> Image exists? True
# [Champagne] Checking JSON: 34609.json -> Image exists? False
# [Champagne] Removed JSON without image: 34609.json
# [Champagne] Checking JSON: 3475.json -> Image exists? True
# [Champagne] Checking JSON: 34936.json -> Image exists? False
# [Champagne] Removed JSON without image: 34936.json
# [Champagne] Checking JSON: 34937.json -> Image exists? False
# [Champagne] Removed JSON without image: 34937.json
# [Champagne] Checking JSON: 34938.json -> Image exists? False
# [Champagne] Removed JSON without image: 34938.json
# [Champagne] Checking JSON: 34939.json -> Image exists? False
# [Champagne] Removed JSON without image: 34939.json
# [Champagne] Checking JSON: 35552.json -> Image exists? True
# [Champagne] Checking JSON: 35703.json -> Image exists? False
# [Champagne] Removed JSON without image: 35703.json
# [Champagne] Checking JSON: 35704.json -> Image exists? False
# [Champagne] Removed JSON without image: 35704.json
# [Champagne] Checking JSON: 35706.json -> Image exists? False
# [Champagne] Removed JSON without image: 35706.json
# [Champagne] Checking JSON: 35910.json -> Image exists? False
# [Champagne] Removed JSON without image: 35910.json
# [Champagne] Checking JSON: 36188.json -> Image exists? True
# [Champagne] Checking JSON: 36189.json -> Image exists? True
# [Champagne] Checking JSON: 365312.json -> Image exists? True
# [Champagne] Checking JSON: 368415.json -> Image exists? True
# [Champagne] Checking JSON: 369678.json -> Image exists? True
# [Champagne] Checking JSON: 36981.json -> Image exists? True
# [Champagne] Checking JSON: 37069.json -> Image exists? True
# [Champagne] Checking JSON: 37901.json -> Image exists? False
# [Champagne] Removed JSON without image: 37901.json
# [Champagne] Checking JSON: 37904.json -> Image exists? False
# [Champagne] Removed JSON without image: 37904.json
# [Champagne] Checking JSON: 37905.json -> Image exists? False
# [Champagne] Removed JSON without image: 37905.json
# [Champagne] Checking JSON: 37906.json -> Image exists? False
# [Champagne] Removed JSON without image: 37906.json
# [Champagne] Checking JSON: 37907.json -> Image exists? False
# [Champagne] Removed JSON without image: 37907.json
# [Champagne] Checking JSON: 38226.json -> Image exists? True
# [Champagne] Checking JSON: 38251.json -> Image exists? True
# [Champagne] Checking JSON: 38262.json -> Image exists? False
# [Champagne] Removed JSON without image: 38262.json
# [Champagne] Checking JSON: 38307.json -> Image exists? True
# [Champagne] Checking JSON: 384529.json -> Image exists? True
# [Champagne] Checking JSON: 38562.json -> Image exists? True
# [Champagne] Checking JSON: 38589.json -> Image exists? True
# [Champagne] Checking JSON: 38616.json -> Image exists? True
# [Champagne] Checking JSON: 38618.json -> Image exists? False
# [Champagne] Removed JSON without image: 38618.json
# [Champagne] Checking JSON: 38619.json -> Image exists? True
# [Champagne] Checking JSON: 38632.json -> Image exists? True
# [Champagne] Checking JSON: 38703.json -> Image exists? True
# [Champagne] Checking JSON: 38723.json -> Image exists? True
# [Champagne] Checking JSON: 38726.json -> Image exists? True
# [Champagne] Checking JSON: 38727.json -> Image exists? True
# [Champagne] Checking JSON: 38742.json -> Image exists? True
# [Champagne] Checking JSON: 38743.json -> Image exists? True
# [Champagne] Checking JSON: 38802.json -> Image exists? True
# [Champagne] Checking JSON: 38812.json -> Image exists? True
# [Champagne] Checking JSON: 38813.json -> Image exists? True
# [Champagne] Checking JSON: 389056.json -> Image exists? True
# [Champagne] Checking JSON: 39368.json -> Image exists? False
# [Champagne] Removed JSON without image: 39368.json
# [Champagne] Checking JSON: 39390.json -> Image exists? True
# [Champagne] Checking JSON: 39832.json -> Image exists? True
# [Champagne] Checking JSON: 39839.json -> Image exists? False
# [Champagne] Removed JSON without image: 39839.json
# [Champagne] Checking JSON: 39864.json -> Image exists? True
# [Champagne] Checking JSON: 39865.json -> Image exists? True
# [Champagne] Checking JSON: 39868.json -> Image exists? True
# [Champagne] Checking JSON: 39869.json -> Image exists? True
# [Champagne] Checking JSON: 39884.json -> Image exists? False
# [Champagne] Removed JSON without image: 39884.json
# [Champagne] Checking JSON: 39885.json -> Image exists? False
# [Champagne] Removed JSON without image: 39885.json
# [Champagne] Checking JSON: 39886.json -> Image exists? False
# [Champagne] Removed JSON without image: 39886.json
# [Champagne] Checking JSON: 40241.json -> Image exists? True
# [Champagne] Checking JSON: 40364.json -> Image exists? False
# [Champagne] Removed JSON without image: 40364.json
# [Champagne] Checking JSON: 40870.json -> Image exists? True
# [Champagne] Checking JSON: 4143.json -> Image exists? False
# [Champagne] Removed JSON without image: 4143.json
# [Champagne] Checking JSON: 421032.json -> Image exists? True
# [Champagne] Checking JSON: 424341.json -> Image exists? True
# [Champagne] Checking JSON: 42841.json -> Image exists? True
# [Champagne] Checking JSON: 43730.json -> Image exists? True
# [Champagne] Checking JSON: 440883.json -> Image exists? True
# [Champagne] Checking JSON: 44273.json -> Image exists? False
# [Champagne] Removed JSON without image: 44273.json
# [Champagne] Checking JSON: 44471.json -> Image exists? True
# [Champagne] Checking JSON: 44472.json -> Image exists? True
# [Champagne] Checking JSON: 44732.json -> Image exists? False
# [Champagne] Removed JSON without image: 44732.json
# [Champagne] Checking JSON: 448688.json -> Image exists? True
# [Champagne] Checking JSON: 44901.json -> Image exists? True
# [Champagne] Checking JSON: 45271.json -> Image exists? True
# [Champagne] Checking JSON: 453076.json -> Image exists? True
# [Champagne] Checking JSON: 453084.json -> Image exists? True
# [Champagne] Checking JSON: 45411.json -> Image exists? True
# [Champagne] Checking JSON: 45449.json -> Image exists? True
# [Champagne] Checking JSON: 45451.json -> Image exists? True
# [Champagne] Checking JSON: 45867.json -> Image exists? True
# [Champagne] Checking JSON: 462432.json -> Image exists? True
# [Champagne] Checking JSON: 46979.json -> Image exists? True
# [Champagne] Checking JSON: 470484.json -> Image exists? True
# [Champagne] Checking JSON: 482026.json -> Image exists? True
# [Champagne] Checking JSON: 483107.json -> Image exists? True
# [Champagne] Checking JSON: 505917.json -> Image exists? True
# [Champagne] Checking JSON: 507889.json -> Image exists? True
# [Champagne] Checking JSON: 508614.json -> Image exists? True
# [Champagne] Checking JSON: 509695.json -> Image exists? True
# [Champagne] Checking JSON: 537605.json -> Image exists? True
# [Champagne] Checking JSON: 549527.json -> Image exists? True
# [Champagne] Checking JSON: 563338.json -> Image exists? True
# [Champagne] Checking JSON: 572586.json -> Image exists? True
# [Champagne] Checking JSON: 588475.json -> Image exists? True
# [Champagne] Checking JSON: 596973.json -> Image exists? True
# [Champagne] Checking JSON: 62984.json -> Image exists? True
# [Champagne] Checking JSON: 63768.json -> Image exists? True
# [Champagne] Checking JSON: 662536.json -> Image exists? True
# [Champagne] Checking JSON: 670364.json -> Image exists? True
# [Champagne] Checking JSON: 69773.json -> Image exists? True
# [Champagne] Checking JSON: 69831.json -> Image exists? True
# [Champagne] Checking JSON: 722180.json -> Image exists? True
# [Champagne] Checking JSON: 8078.json -> Image exists? False
# [Champagne] Removed JSON without image: 8078.json
# [Champagne] Checking JSON: 91777.json -> Image exists? True
# [Champagne] Checking JSON: 92072.json -> Image exists? True
# [Champagne] Checking JSON: 922962.json -> Image exists? True
# [Champagne] Checking JSON: 924654.json -> Image exists? True
# [Champagne] Checking JSON: 93054.json -> Image exists? True
# [Champagne] Checking JSON: 93062.json -> Image exists? True
# [Champagne] Checking JSON: 933606.json -> Image exists? True
# [Champagne] Checking JSON: 955633.json -> Image exists? True
# [Champagne] Checking JSON: 96685.json -> Image exists? False
# [Champagne] Removed JSON without image: 96685.json
# [Champagne] Checking JSON: 969162.json -> Image exists? True
# [Champagne] Checking JSON: 981027.json -> Image exists? True
# [Champagne] Checking JSON: 990796.json -> Image exists? True
# [Champagne] Checking JSON: 993378.json -> Image exists? True
# [Dessert] Checking JSON: 156588.json -> Image exists? True
# [Dessert] Checking JSON: 16974.json -> Image exists? True
# [Dessert] Checking JSON: 17100013.json -> Image exists? True
# [Dessert] Checking JSON: 17100014.json -> Image exists? True
# [Dessert] Checking JSON: 17100017.json -> Image exists? True
# [Dessert] Checking JSON: 17100108.json -> Image exists? True
# [Dessert] Checking JSON: 17100841.json -> Image exists? True
# [Dessert] Checking JSON: 17101424.json -> Image exists? True
# [Dessert] Checking JSON: 17101539.json -> Image exists? True
# [Dessert] Checking JSON: 17101610.json -> Image exists? True
# [Dessert] Checking JSON: 17101660.json -> Image exists? True
# [Dessert] Checking JSON: 17101847.json -> Image exists? True
# [Dessert] Checking JSON: 17102055.json -> Image exists? True
# [Dessert] Checking JSON: 17102304.json -> Image exists? True
# [Dessert] Checking JSON: 17102341.json -> Image exists? True
# [Dessert] Checking JSON: 17102448.json -> Image exists? True
# [Dessert] Checking JSON: 17103423.json -> Image exists? True
# [Dessert] Checking JSON: 17103471.json -> Image exists? True
# [Dessert] Checking JSON: 17104026.json -> Image exists? True
# [Dessert] Checking JSON: 17104797.json -> Image exists? True
# [Dessert] Checking JSON: 17104821.json -> Image exists? True
# [Dessert] Checking JSON: 17104878.json -> Image exists? True
# [Dessert] Checking JSON: 17104976.json -> Image exists? True
# [Dessert] Checking JSON: 17105004.json -> Image exists? True
# [Dessert] Checking JSON: 17105141.json -> Image exists? True
# [Dessert] Checking JSON: 17105364.json -> Image exists? True
# [Dessert] Checking JSON: 17105748.json -> Image exists? True
# [Dessert] Checking JSON: 17105763.json -> Image exists? True
# [Dessert] Checking JSON: 17105770.json -> Image exists? True
# [Dessert] Checking JSON: 17105911.json -> Image exists? True
# [Dessert] Checking JSON: 17105969.json -> Image exists? True
# [Dessert] Checking JSON: 17107030.json -> Image exists? True
# [Dessert] Checking JSON: 17107183.json -> Image exists? True
# [Dessert] Checking JSON: 17107691.json -> Image exists? True
# [Dessert] Checking JSON: 17108681.json -> Image exists? True
# [Dessert] Checking JSON: 17110680.json -> Image exists? True
# [Dessert] Checking JSON: 17111328.json -> Image exists? True
# [Dessert] Checking JSON: 17111478.json -> Image exists? True
# [Dessert] Checking JSON: 17113695.json -> Image exists? True
# [Dessert] Checking JSON: 17126285.json -> Image exists? True
# [Dessert] Checking JSON: 17127658.json -> Image exists? True
# [Dessert] Checking JSON: 17138829.json -> Image exists? True
# [Dessert] Checking JSON: 17142875.json -> Image exists? True
# [Dessert] Checking JSON: 17143130.json -> Image exists? True
# [Dessert] Checking JSON: 17143222.json -> Image exists? True
# [Dessert] Checking JSON: 17144337.json -> Image exists? True
# [Dessert] Checking JSON: 17144632.json -> Image exists? True
# [Dessert] Checking JSON: 17147123.json -> Image exists? True
# [Dessert] Checking JSON: 17151878.json -> Image exists? True
# [Dessert] Checking JSON: 17153536.json -> Image exists? True
# [Dessert] Checking JSON: 17153810.json -> Image exists? True
# [Dessert] Checking JSON: 17154979.json -> Image exists? True
# [Dessert] Checking JSON: 17155628.json -> Image exists? True
# [Dessert] Checking JSON: 17159275.json -> Image exists? True
# [Dessert] Checking JSON: 17160271.json -> Image exists? True
# [Dessert] Checking JSON: 17160277.json -> Image exists? True
# [Dessert] Checking JSON: 17161471.json -> Image exists? True
# [Dessert] Checking JSON: 17162455.json -> Image exists? True
# [Dessert] Checking JSON: 17164220.json -> Image exists? True
# [Dessert] Checking JSON: 17164945.json -> Image exists? True
# [Dessert] Checking JSON: 17170599.json -> Image exists? True
# [Dessert] Checking JSON: 17172065.json -> Image exists? True
# [Dessert] Checking JSON: 17172833.json -> Image exists? True
# [Dessert] Checking JSON: 17173765.json -> Image exists? True
# [Dessert] Checking JSON: 17174121.json -> Image exists? True
# [Dessert] Checking JSON: 17178378.json -> Image exists? True
# [Dessert] Checking JSON: 17180712.json -> Image exists? True
# [Dessert] Checking JSON: 17181062.json -> Image exists? True
# [Dessert] Checking JSON: 17186159.json -> Image exists? True
# [Dessert] Checking JSON: 17187963.json -> Image exists? True
# [Dessert] Checking JSON: 17188120.json -> Image exists? True
# [Dessert] Checking JSON: 17189939.json -> Image exists? True
# [Dessert] Checking JSON: 17190485.json -> Image exists? True
# [Dessert] Checking JSON: 17192560.json -> Image exists? True
# [Dessert] Checking JSON: 17192645.json -> Image exists? True
# [Dessert] Checking JSON: 17192711.json -> Image exists? True
# [Dessert] Checking JSON: 17192749.json -> Image exists? True
# [Dessert] Checking JSON: 17193172.json -> Image exists? True
# [Dessert] Checking JSON: 17194594.json -> Image exists? True
# [Dessert] Checking JSON: 17194674.json -> Image exists? True
# [Dessert] Checking JSON: 17194769.json -> Image exists? True
# [Dessert] Checking JSON: 17195939.json -> Image exists? True
# [Dessert] Checking JSON: 17196091.json -> Image exists? True
# [Dessert] Checking JSON: 17196531.json -> Image exists? True
# [Dessert] Checking JSON: 17199204.json -> Image exists? True
# [Dessert] Checking JSON: 17199306.json -> Image exists? True
# [Dessert] Checking JSON: 208413.json -> Image exists? True
# [Dessert] Checking JSON: 26704.json -> Image exists? True
# [Dessert] Checking JSON: 27734.json -> Image exists? True
# [Dessert] Checking JSON: 28665.json -> Image exists? False
# [Dessert] Removed JSON without image: 28665.json
# [Dessert] Checking JSON: 292797.json -> Image exists? True
# [Dessert] Checking JSON: 324723.json -> Image exists? True
# [Dessert] Checking JSON: 32682.json -> Image exists? True
# [Dessert] Checking JSON: 34715.json -> Image exists? True
# [Dessert] Checking JSON: 34809.json -> Image exists? True
# [Dessert] Checking JSON: 36236.json -> Image exists? False
# [Dessert] Removed JSON without image: 36236.json
# [Dessert] Checking JSON: 395707.json -> Image exists? True
# [Dessert] Checking JSON: 39631.json -> Image exists? False
# [Dessert] Removed JSON without image: 39631.json
# [Dessert] Checking JSON: 39632.json -> Image exists? False
# [Dessert] Removed JSON without image: 39632.json
# [Dessert] Checking JSON: 39634.json -> Image exists? False
# [Dessert] Removed JSON without image: 39634.json
# [Dessert] Checking JSON: 39738.json -> Image exists? True
# [Dessert] Checking JSON: 415901.json -> Image exists? True
# [Dessert] Checking JSON: 42249.json -> Image exists? True
# [Dessert] Checking JSON: 43395.json -> Image exists? True
# [Dessert] Checking JSON: 43607.json -> Image exists? True
# [Dessert] Checking JSON: 437319.json -> Image exists? True
# [Dessert] Checking JSON: 44475.json -> Image exists? True
# [Dessert] Checking JSON: 47209.json -> Image exists? True
# [Dessert] Checking JSON: 488668.json -> Image exists? True
# [Dessert] Checking JSON: 5033.json -> Image exists? True
# [Dessert] Checking JSON: 522433.json -> Image exists? True
# [Dessert] Checking JSON: 559062.json -> Image exists? True
# [Dessert] Checking JSON: 631341.json -> Image exists? True
# [Fortified] Checking JSON: 1008.json -> Image exists? False
# [Fortified] Removed JSON without image: 1008.json
# [Fortified] Checking JSON: 10812.json -> Image exists? True
# [Fortified] Checking JSON: 111476.json -> Image exists? True
# [Fortified] Checking JSON: 112789.json -> Image exists? True
# [Fortified] Checking JSON: 121749.json -> Image exists? True
# [Fortified] Checking JSON: 12971.json -> Image exists? True
# [Fortified] Checking JSON: 13565.json -> Image exists? True
# [Fortified] Checking JSON: 139758.json -> Image exists? True
# [Fortified] Checking JSON: 14052.json -> Image exists? True
# [Fortified] Checking JSON: 149047.json -> Image exists? True
# [Fortified] Checking JSON: 157586.json -> Image exists? True
# [Fortified] Checking JSON: 16139.json -> Image exists? True
# [Fortified] Checking JSON: 164111.json -> Image exists? True
# [Fortified] Checking JSON: 16974.json -> Image exists? True
# [Fortified] Checking JSON: 17510.json -> Image exists? True
# [Fortified] Checking JSON: 18475.json -> Image exists? True
# [Fortified] Checking JSON: 18652.json -> Image exists? False
# [Fortified] Removed JSON without image: 18652.json
# [Fortified] Checking JSON: 191239.json -> Image exists? True
# [Fortified] Checking JSON: 19265.json -> Image exists? True
# [Fortified] Checking JSON: 19273.json -> Image exists? True
# [Fortified] Checking JSON: 208405.json -> Image exists? True
# [Fortified] Checking JSON: 208413.json -> Image exists? True
# [Fortified] Checking JSON: 215483.json -> Image exists? True
# [Fortified] Checking JSON: 215897.json -> Image exists? True
# [Fortified] Checking JSON: 21737.json -> Image exists? True
# [Fortified] Checking JSON: 21830.json -> Image exists? True
# [Fortified] Checking JSON: 223867.json -> Image exists? True
# [Fortified] Checking JSON: 223958.json -> Image exists? True
# [Fortified] Checking JSON: 231829.json -> Image exists? True
# [Fortified] Checking JSON: 23366.json -> Image exists? True
# [Fortified] Checking JSON: 235689.json -> Image exists? True
# [Fortified] Checking JSON: 25602.json -> Image exists? True
# [Fortified] Checking JSON: 256859.json -> Image exists? False
# [Fortified] Removed JSON without image: 256859.json
# [Fortified] Checking JSON: 26191.json -> Image exists? True
# [Fortified] Checking JSON: 26197.json -> Image exists? True
# [Fortified] Checking JSON: 264721.json -> Image exists? True
# [Fortified] Checking JSON: 26604.json -> Image exists? True
# [Fortified] Checking JSON: 26675.json -> Image exists? False
# [Fortified] Removed JSON without image: 26675.json
# [Fortified] Checking JSON: 26846.json -> Image exists? False
# [Fortified] Removed JSON without image: 26846.json
# [Fortified] Checking JSON: 26860.json -> Image exists? True
# [Fortified] Checking JSON: 26959.json -> Image exists? True
# [Fortified] Checking JSON: 26960.json -> Image exists? True
# [Fortified] Checking JSON: 27139.json -> Image exists? True
# [Fortified] Checking JSON: 27375.json -> Image exists? True
# [Fortified] Checking JSON: 274505.json -> Image exists? False
# [Fortified] Removed JSON without image: 274505.json
# [Fortified] Checking JSON: 274513.json -> Image exists? False
# [Fortified] Removed JSON without image: 274513.json
# [Fortified] Checking JSON: 274521.json -> Image exists? False
# [Fortified] Removed JSON without image: 274521.json
# [Fortified] Checking JSON: 27485.json -> Image exists? True
# [Fortified] Checking JSON: 276816.json -> Image exists? True
# [Fortified] Checking JSON: 28155.json -> Image exists? True
# [Fortified] Checking JSON: 283233.json -> Image exists? False
# [Fortified] Removed JSON without image: 283233.json
# [Fortified] Checking JSON: 289453.json -> Image exists? True
# [Fortified] Checking JSON: 290718.json -> Image exists? True
# [Fortified] Checking JSON: 305226.json -> Image exists? True
# [Fortified] Checking JSON: 30892.json -> Image exists? True
# [Fortified] Checking JSON: 30893.json -> Image exists? False
# [Fortified] Removed JSON without image: 30893.json
# [Fortified] Checking JSON: 30930.json -> Image exists? False
# [Fortified] Removed JSON without image: 30930.json
# [Fortified] Checking JSON: 309401.json -> Image exists? True
# [Fortified] Checking JSON: 310176.json -> Image exists? True
# [Fortified] Checking JSON: 310226.json -> Image exists? True
# [Fortified] Checking JSON: 31120.json -> Image exists? True
# [Fortified] Checking JSON: 31676.json -> Image exists? True
# [Fortified] Checking JSON: 31737.json -> Image exists? True
# [Fortified] Checking JSON: 31766.json -> Image exists? True
# [Fortified] Checking JSON: 31767.json -> Image exists? True
# [Fortified] Checking JSON: 31768.json -> Image exists? True
# [Fortified] Checking JSON: 31778.json -> Image exists? True
# [Fortified] Checking JSON: 31782.json -> Image exists? True
# [Fortified] Checking JSON: 31783.json -> Image exists? True
# [Fortified] Checking JSON: 31784.json -> Image exists? True
# [Fortified] Checking JSON: 31818.json -> Image exists? True
# [Fortified] Checking JSON: 31909.json -> Image exists? True
# [Fortified] Checking JSON: 31911.json -> Image exists? True
# [Fortified] Checking JSON: 31983.json -> Image exists? True
# [Fortified] Checking JSON: 325506.json -> Image exists? True
# [Fortified] Checking JSON: 33021.json -> Image exists? True
# [Fortified] Checking JSON: 33189.json -> Image exists? True
# [Fortified] Checking JSON: 33360.json -> Image exists? True
# [Fortified] Checking JSON: 33362.json -> Image exists? True
# [Fortified] Checking JSON: 33391.json -> Image exists? True
# [Fortified] Checking JSON: 337022.json -> Image exists? True
# [Fortified] Checking JSON: 33710.json -> Image exists? True
# [Fortified] Checking JSON: 33813.json -> Image exists? True
# [Fortified] Checking JSON: 33932.json -> Image exists? False
# [Fortified] Removed JSON without image: 33932.json
# [Fortified] Checking JSON: 33933.json -> Image exists? True
# [Fortified] Checking JSON: 33937.json -> Image exists? True
# [Fortified] Checking JSON: 33940.json -> Image exists? True
# [Fortified] Checking JSON: 33949.json -> Image exists? True
# [Fortified] Checking JSON: 342931.json -> Image exists? True
# [Fortified] Checking JSON: 34376.json -> Image exists? True
# [Fortified] Checking JSON: 34377.json -> Image exists? True
# [Fortified] Checking JSON: 34516.json -> Image exists? True
# [Fortified] Checking JSON: 34518.json -> Image exists? True
# [Fortified] Checking JSON: 34521.json -> Image exists? True
# [Fortified] Checking JSON: 34522.json -> Image exists? True
# [Fortified] Checking JSON: 34541.json -> Image exists? True
# [Fortified] Checking JSON: 34542.json -> Image exists? True
# [Fortified] Checking JSON: 34543.json -> Image exists? True
# [Fortified] Checking JSON: 34565.json -> Image exists? False
# [Fortified] Removed JSON without image: 34565.json
# [Fortified] Checking JSON: 34676.json -> Image exists? True
# [Fortified] Checking JSON: 34679.json -> Image exists? True
# [Fortified] Checking JSON: 34680.json -> Image exists? True
# [Fortified] Checking JSON: 34810.json -> Image exists? True
# [Fortified] Checking JSON: 34954.json -> Image exists? True
# [Fortified] Checking JSON: 35043.json -> Image exists? True
# [Fortified] Checking JSON: 35199.json -> Image exists? True
# [Fortified] Checking JSON: 35200.json -> Image exists? True
# [Fortified] Checking JSON: 35204.json -> Image exists? True
# [Fortified] Checking JSON: 35657.json -> Image exists? True
# [Fortified] Checking JSON: 35660.json -> Image exists? True
# [Fortified] Checking JSON: 35748.json -> Image exists? True
# [Fortified] Checking JSON: 35766.json -> Image exists? True
# [Fortified] Checking JSON: 368109.json -> Image exists? False
# [Fortified] Removed JSON without image: 368109.json
# [Fortified] Checking JSON: 375097.json -> Image exists? True
# [Fortified] Checking JSON: 37585.json -> Image exists? True
# [Fortified] Checking JSON: 37675.json -> Image exists? True
# [Fortified] Checking JSON: 37676.json -> Image exists? True
# [Fortified] Checking JSON: 378919.json -> Image exists? True
# [Fortified] Checking JSON: 38390.json -> Image exists? True
# [Fortified] Checking JSON: 38643.json -> Image exists? True
# [Fortified] Checking JSON: 39010.json -> Image exists? True
# [Fortified] Checking JSON: 39048.json -> Image exists? True
# [Fortified] Checking JSON: 39459.json -> Image exists? True
# [Fortified] Checking JSON: 39463.json -> Image exists? True
# [Fortified] Checking JSON: 39464.json -> Image exists? True
# [Fortified] Checking JSON: 39467.json -> Image exists? True
# [Fortified] Checking JSON: 39703.json -> Image exists? True
# [Fortified] Checking JSON: 39704.json -> Image exists? True
# [Fortified] Checking JSON: 39753.json -> Image exists? True
# [Fortified] Checking JSON: 39823.json -> Image exists? True
# [Fortified] Checking JSON: 39824.json -> Image exists? True
# [Fortified] Checking JSON: 39827.json -> Image exists? True
# [Fortified] Checking JSON: 39953.json -> Image exists? True
# [Fortified] Checking JSON: 400515.json -> Image exists? True
# [Fortified] Checking JSON: 402354.json -> Image exists? True
# [Fortified] Checking JSON: 404012.json -> Image exists? True
# [Fortified] Checking JSON: 40448.json -> Image exists? True
# [Fortified] Checking JSON: 42114.json -> Image exists? True
# [Fortified] Checking JSON: 42116.json -> Image exists? True
# [Fortified] Checking JSON: 42121.json -> Image exists? True
# [Fortified] Checking JSON: 42271.json -> Image exists? True
# [Fortified] Checking JSON: 42297.json -> Image exists? True
# [Fortified] Checking JSON: 42452.json -> Image exists? True
# [Fortified] Checking JSON: 42892.json -> Image exists? True
# [Fortified] Checking JSON: 42916.json -> Image exists? True
# [Fortified] Checking JSON: 42963.json -> Image exists? True
# [Fortified] Checking JSON: 42991.json -> Image exists? True
# [Fortified] Checking JSON: 43035.json -> Image exists? True
# [Fortified] Checking JSON: 430934.json -> Image exists? False
# [Fortified] Removed JSON without image: 430934.json
# [Fortified] Checking JSON: 43307.json -> Image exists? True
# [Fortified] Checking JSON: 43423.json -> Image exists? True
# [Fortified] Checking JSON: 43526.json -> Image exists? True
# [Fortified] Checking JSON: 43543.json -> Image exists? False
# [Fortified] Removed JSON without image: 43543.json
# [Fortified] Checking JSON: 4382.json -> Image exists? True
# [Fortified] Checking JSON: 43946.json -> Image exists? True
# [Fortified] Checking JSON: 44303.json -> Image exists? True
# [Fortified] Checking JSON: 44628.json -> Image exists? True
# [Fortified] Checking JSON: 44968.json -> Image exists? True
# [Fortified] Checking JSON: 45361.json -> Image exists? True
# [Fortified] Checking JSON: 46586.json -> Image exists? False
# [Fortified] Removed JSON without image: 46586.json
# [Fortified] Checking JSON: 46610.json -> Image exists? False
# [Fortified] Removed JSON without image: 46610.json
# [Fortified] Checking JSON: 46681.json -> Image exists? False
# [Fortified] Removed JSON without image: 46681.json
# [Fortified] Checking JSON: 46946.json -> Image exists? True
# [Fortified] Checking JSON: 471078.json -> Image exists? True
# [Fortified] Checking JSON: 491712.json -> Image exists? True
# [Fortified] Checking JSON: 492660.json -> Image exists? True
# [Fortified] Checking JSON: 515965.json -> Image exists? True
# [Fortified] Checking JSON: 538983.json -> Image exists? True
# [Fortified] Checking JSON: 542746.json -> Image exists? True
# [Fortified] Checking JSON: 542852.json -> Image exists? True
# [Fortified] Checking JSON: 546838.json -> Image exists? True
# [Fortified] Checking JSON: 553990.json -> Image exists? True
# [Fortified] Checking JSON: 558999.json -> Image exists? True
# [Fortified] Checking JSON: 571133.json -> Image exists? True
# [Fortified] Checking JSON: 571604.json -> Image exists? False
# [Fortified] Removed JSON without image: 571604.json
# [Fortified] Checking JSON: 578682.json -> Image exists? True
# [Fortified] Checking JSON: 620641.json -> Image exists? True
# [Fortified] Checking JSON: 625988.json -> Image exists? True
# [Fortified] Checking JSON: 645267.json -> Image exists? True
# [Fortified] Checking JSON: 660753.json -> Image exists? False
# [Fortified] Removed JSON without image: 660753.json
# [Fortified] Checking JSON: 70086.json -> Image exists? True
# [Fortified] Checking JSON: 745448.json -> Image exists? True
# [Fortified] Checking JSON: 793844.json -> Image exists? True
# [Fortified] Checking JSON: 793885.json -> Image exists? True
# [Fortified] Checking JSON: 834010.json -> Image exists? True
# [Fortified] Checking JSON: 834051.json -> Image exists? False
# [Fortified] Removed JSON without image: 834051.json
# [Fortified] Checking JSON: 834069.json -> Image exists? False
# [Fortified] Removed JSON without image: 834069.json
# [Fortified] Checking JSON: 87205.json -> Image exists? True
# [Fortified] Checking JSON: 90860.json -> Image exists? True
# [Fortified] Checking JSON: 922757.json -> Image exists? False
# [Fortified] Removed JSON without image: 922757.json
# [Fortified] Checking JSON: 950436.json -> Image exists? True
# [Fortified] Checking JSON: 970268.json -> Image exists? False
# [Fortified] Removed JSON without image: 970268.json
# [Fortified] Checking JSON: 975797.json -> Image exists? True
# [Icewine] Checking JSON: 13418.json -> Image exists? True
# [Icewine] Checking JSON: 149963.json -> Image exists? True
# [Icewine] Checking JSON: 18564.json -> Image exists? True
# [Icewine] Checking JSON: 19083.json -> Image exists? True
# [Icewine] Checking JSON: 23864.json -> Image exists? True
# [Icewine] Checking JSON: 28465.json -> Image exists? True
# [Icewine] Checking JSON: 28709.json -> Image exists? True
# [Icewine] Checking JSON: 34905.json -> Image exists? True
# [Icewine] Checking JSON: 35298.json -> Image exists? True
# [Icewine] Checking JSON: 35414.json -> Image exists? True
# [Icewine] Checking JSON: 359133.json -> Image exists? True
# [Icewine] Checking JSON: 359539.json -> Image exists? True
# [Icewine] Checking JSON: 37394.json -> Image exists? True
# [Icewine] Checking JSON: 38144.json -> Image exists? True
# [Icewine] Checking JSON: 388306.json -> Image exists? True
# [Icewine] Checking JSON: 389411.json -> Image exists? True
# [Icewine] Checking JSON: 390351.json -> Image exists? True
# [Icewine] Checking JSON: 413732.json -> Image exists? True
# [Icewine] Checking JSON: 41733.json -> Image exists? True
# [Icewine] Checking JSON: 42487.json -> Image exists? True
# [Icewine] Checking JSON: 42491.json -> Image exists? True
# [Icewine] Checking JSON: 42786.json -> Image exists? True
# [Icewine] Checking JSON: 430561.json -> Image exists? True
# [Icewine] Checking JSON: 44186.json -> Image exists? True
# [Icewine] Checking JSON: 443820.json -> Image exists? True
# [Icewine] Checking JSON: 447441.json -> Image exists? True
# [Icewine] Checking JSON: 45140.json -> Image exists? False
# [Icewine] Removed JSON without image: 45140.json
# [Icewine] Checking JSON: 465203.json -> Image exists? True
# [Icewine] Checking JSON: 467746.json -> Image exists? True
# [Icewine] Checking JSON: 471813.json -> Image exists? True
# [Icewine] Checking JSON: 471839.json -> Image exists? True
# [Icewine] Checking JSON: 476192.json -> Image exists? True
# [Icewine] Checking JSON: 47782.json -> Image exists? False
# [Icewine] Removed JSON without image: 47782.json
# [Icewine] Checking JSON: 484048.json -> Image exists? True
# [Icewine] Checking JSON: 522672.json -> Image exists? True
# [Icewine] Checking JSON: 53397.json -> Image exists? True
# [Icewine] Checking JSON: 542530.json -> Image exists? True
# [Icewine] Checking JSON: 544791.json -> Image exists? True
# [Icewine] Checking JSON: 547703.json -> Image exists? True
# [Icewine] Checking JSON: 558288.json -> Image exists? True
# [Icewine] Checking JSON: 558452.json -> Image exists? True
# [Icewine] Checking JSON: 558999.json -> Image exists? True
# [Icewine] Checking JSON: 559302.json -> Image exists? True
# [Icewine] Checking JSON: 560367.json -> Image exists? True
# [Icewine] Checking JSON: 563247.json -> Image exists? True
# [Icewine] Checking JSON: 565861.json -> Image exists? True
# [Icewine] Checking JSON: 56671.json -> Image exists? True
# [Icewine] Checking JSON: 582247.json -> Image exists? True
# [Icewine] Checking JSON: 587154.json -> Image exists? True
# [Icewine] Checking JSON: 646505.json -> Image exists? True
# [Icewine] Checking JSON: 672402.json -> Image exists? True
# [Red] Checking JSON: 104653.json -> Image exists? True
# [Red] Checking JSON: 105429.json -> Image exists? True
# [Red] Checking JSON: 106377.json -> Image exists? True
# [Red] Checking JSON: 107276.json -> Image exists? True
# [Red] Checking JSON: 10948.json -> Image exists? True
# [Red] Checking JSON: 10971.json -> Image exists? True
# [Red] Checking JSON: 10994.json -> Image exists? True
# [Red] Checking JSON: 111526.json -> Image exists? True
# [Red] Checking JSON: 111641.json -> Image exists? True
# [Red] Checking JSON: 11195.json -> Image exists? True
# [Red] Checking JSON: 116426.json -> Image exists? True
# [Red] Checking JSON: 11927.json -> Image exists? True
# [Red] Checking JSON: 11933.json -> Image exists? True
# [Red] Checking JSON: 121160.json -> Image exists? True
# [Red] Checking JSON: 121723.json -> Image exists? True
# [Red] Checking JSON: 121731.json -> Image exists? True
# [Red] Checking JSON: 122077.json -> Image exists? True
# [Red] Checking JSON: 12258.json -> Image exists? False
# [Red] Removed JSON without image: 12258.json
# [Red] Checking JSON: 12286.json -> Image exists? True
# [Red] Checking JSON: 123489.json -> Image exists? True
# [Red] Checking JSON: 123653.json -> Image exists? False
# [Red] Removed JSON without image: 123653.json
# [Red] Checking JSON: 12452.json -> Image exists? True
# [Red] Checking JSON: 127456.json -> Image exists? True
# [Red] Checking JSON: 12777.json -> Image exists? True
# [Red] Checking JSON: 12990.json -> Image exists? True
# [Red] Checking JSON: 13454.json -> Image exists? True
# [Red] Checking JSON: 13462.json -> Image exists? True
# [Red] Checking JSON: 13494.json -> Image exists? True
# [Red] Checking JSON: 135475.json -> Image exists? True
# [Red] Checking JSON: 13632.json -> Image exists? True
# [Red] Checking JSON: 137810.json -> Image exists? True
# [Red] Checking JSON: 141580.json -> Image exists? True
# [Red] Checking JSON: 141952.json -> Image exists? True
# [Red] Checking JSON: 142406.json -> Image exists? True
# [Red] Checking JSON: 142935.json -> Image exists? True
# [Red] Checking JSON: 143578.json -> Image exists? True
# [Red] Checking JSON: 143735.json -> Image exists? True
# [Red] Checking JSON: 143750.json -> Image exists? True
# [Red] Checking JSON: 14388.json -> Image exists? True
# [Red] Checking JSON: 144493.json -> Image exists? True
# [Red] Checking JSON: 145367.json -> Image exists? True
# [Red] Checking JSON: 145920.json -> Image exists? True
# [Red] Checking JSON: 146449.json -> Image exists? True
# [Red] Checking JSON: 147876.json -> Image exists? True
# [Red] Checking JSON: 14967.json -> Image exists? True
# [Red] Checking JSON: 14970.json -> Image exists? False
# [Red] Removed JSON without image: 14970.json
# [Red] Checking JSON: 15184.json -> Image exists? True
# [Red] Checking JSON: 152587.json -> Image exists? True
# [Red] Checking JSON: 15285.json -> Image exists? True
# [Red] Checking JSON: 15376.json -> Image exists? True
# [Red] Checking JSON: 15495.json -> Image exists? True
# [Red] Checking JSON: 155051.json -> Image exists? True
# [Red] Checking JSON: 15658.json -> Image exists? True
# [Red] Checking JSON: 15714.json -> Image exists? False
# [Red] Removed JSON without image: 15714.json
# [Red] Checking JSON: 157883.json -> Image exists? True
# [Red] Checking JSON: 158741.json -> Image exists? True
# [Red] Checking JSON: 15941.json -> Image exists? True
# [Red] Checking JSON: 160143.json -> Image exists? True
# [Red] Checking JSON: 16090.json -> Image exists? True
# [Red] Checking JSON: 160952.json -> Image exists? True
# [Red] Checking JSON: 160994.json -> Image exists? True
# [Red] Checking JSON: 162073.json -> Image exists? True
# [Red] Checking JSON: 162321.json -> Image exists? True
# [Red] Checking JSON: 162610.json -> Image exists? True
# [Red] Checking JSON: 163311.json -> Image exists? True
# [Red] Checking JSON: 16361.json -> Image exists? True
# [Red] Checking JSON: 16363.json -> Image exists? True
# [Red] Checking JSON: 165662.json -> Image exists? True
# [Red] Checking JSON: 16586.json -> Image exists? True
# [Red] Checking JSON: 16587.json -> Image exists? True
# [Red] Checking JSON: 16589.json -> Image exists? False
# [Red] Removed JSON without image: 16589.json
# [Red] Checking JSON: 166199.json -> Image exists? True
# [Red] Checking JSON: 166538.json -> Image exists? True
# [Red] Checking JSON: 16678.json -> Image exists? False
# [Red] Removed JSON without image: 16678.json
# [Red] Checking JSON: 166959.json -> Image exists? True
# [Red] Checking JSON: 16726.json -> Image exists? True
# [Red] Checking JSON: 168179.json -> Image exists? True
# [Red] Checking JSON: 16840.json -> Image exists? True
# [Red] Checking JSON: 169052.json -> Image exists? True
# [Red] Checking JSON: 169888.json -> Image exists? True
# [Red] Checking JSON: 170142.json -> Image exists? True
# [Red] Checking JSON: 17100002.json -> Image exists? True
# [Red] Checking JSON: 17100003.json -> Image exists? True
# [Red] Checking JSON: 17100005.json -> Image exists? True
# [Red] Checking JSON: 17100008.json -> Image exists? True
# [Red] Checking JSON: 17100010.json -> Image exists? True
# [Red] Checking JSON: 17100016.json -> Image exists? True
# [Red] Checking JSON: 17100018.json -> Image exists? True
# [Red] Checking JSON: 17100019.json -> Image exists? True
# [Red] Checking JSON: 17100021.json -> Image exists? True
# [Red] Checking JSON: 17100046.json -> Image exists? True
# [Red] Checking JSON: 17100049.json -> Image exists? True
# [Red] Checking JSON: 17100052.json -> Image exists? True
# [Red] Checking JSON: 17100055.json -> Image exists? True
# [Red] Checking JSON: 17100060.json -> Image exists? True
# [Red] Checking JSON: 17100062.json -> Image exists? True
# [Red] Checking JSON: 17100063.json -> Image exists? True
# [Red] Checking JSON: 17100080.json -> Image exists? True
# [Red] Checking JSON: 17100114.json -> Image exists? True
# [Red] Checking JSON: 17100120.json -> Image exists? True
# [Red] Checking JSON: 17100207.json -> Image exists? True
# [Red] Checking JSON: 17101154.json -> Image exists? True
# [Red] Checking JSON: 17101213.json -> Image exists? True
# [Red] Checking JSON: 17101563.json -> Image exists? True
# [Red] Checking JSON: 17101566.json -> Image exists? True
# [Red] Checking JSON: 17101567.json -> Image exists? True
# [Red] Checking JSON: 17101570.json -> Image exists? True
# [Red] Checking JSON: 17101576.json -> Image exists? True
# [Red] Checking JSON: 17101584.json -> Image exists? True
# [Red] Checking JSON: 17101592.json -> Image exists? True
# [Red] Checking JSON: 17101595.json -> Image exists? True
# [Red] Checking JSON: 17101617.json -> Image exists? True
# [Red] Checking JSON: 17101644.json -> Image exists? True
# [Red] Checking JSON: 17101651.json -> Image exists? True
# [Red] Checking JSON: 17101677.json -> Image exists? True
# [Red] Checking JSON: 17101678.json -> Image exists? True
# [Red] Checking JSON: 17101693.json -> Image exists? True
# [Red] Checking JSON: 17101701.json -> Image exists? True
# [Red] Checking JSON: 17101713.json -> Image exists? True
# [Red] Checking JSON: 17101783.json -> Image exists? True
# [Red] Checking JSON: 17101874.json -> Image exists? True
# [Red] Checking JSON: 17102126.json -> Image exists? True
# [Red] Checking JSON: 17102466.json -> Image exists? True
# [Red] Checking JSON: 17102902.json -> Image exists? True
# [Red] Checking JSON: 17102950.json -> Image exists? True
# [Red] Checking JSON: 17103070.json -> Image exists? True
# [Red] Checking JSON: 17103433.json -> Image exists? True
# [Red] Checking JSON: 17103435.json -> Image exists? True
# [Red] Checking JSON: 17103474.json -> Image exists? True
# [Red] Checking JSON: 17103637.json -> Image exists? True
# [Red] Checking JSON: 17103989.json -> Image exists? True
# [Red] Checking JSON: 17105488.json -> Image exists? True
# [Red] Checking JSON: 17105585.json -> Image exists? True
# [Red] Checking JSON: 17105599.json -> Image exists? True
# [Red] Checking JSON: 17105787.json -> Image exists? True
# [Red] Checking JSON: 17106004.json -> Image exists? True
# [Red] Checking JSON: 17106091.json -> Image exists? True
# [Red] Checking JSON: 17106629.json -> Image exists? True
# [Red] Checking JSON: 17106635.json -> Image exists? True
# [Red] Checking JSON: 17106668.json -> Image exists? True
# [Red] Checking JSON: 17106669.json -> Image exists? True
# [Red] Checking JSON: 17106688.json -> Image exists? True
# [Red] Checking JSON: 17106748.json -> Image exists? True
# [Red] Checking JSON: 17106752.json -> Image exists? True
# [Red] Checking JSON: 17106803.json -> Image exists? True
# [Red] Checking JSON: 17106831.json -> Image exists? True
# [Red] Checking JSON: 17106867.json -> Image exists? True
# [Red] Checking JSON: 17108705.json -> Image exists? True
# [Red] Checking JSON: 17108974.json -> Image exists? True
# [Red] Checking JSON: 17109547.json -> Image exists? True
# [Red] Checking JSON: 17109705.json -> Image exists? True
# [Red] Checking JSON: 17109826.json -> Image exists? True
# [Red] Checking JSON: 17109954.json -> Image exists? True
# [Red] Checking JSON: 17110334.json -> Image exists? True
# [Red] Checking JSON: 17111395.json -> Image exists? True
# [Red] Checking JSON: 17111398.json -> Image exists? True
# [Red] Checking JSON: 17111415.json -> Image exists? True
# [Red] Checking JSON: 17111417.json -> Image exists? True
# [Red] Checking JSON: 17111420.json -> Image exists? True
# [Red] Checking JSON: 17111421.json -> Image exists? True
# [Red] Checking JSON: 17111422.json -> Image exists? True
# [Red] Checking JSON: 17111429.json -> Image exists? True
# [Red] Checking JSON: 17111431.json -> Image exists? True
# [Red] Checking JSON: 17111433.json -> Image exists? True
# [Red] Checking JSON: 17111434.json -> Image exists? True
# [Red] Checking JSON: 17111445.json -> Image exists? True
# [Red] Checking JSON: 17111457.json -> Image exists? True
# [Red] Checking JSON: 17111458.json -> Image exists? True
# [Red] Checking JSON: 17111475.json -> Image exists? True
# [Red] Checking JSON: 17111495.json -> Image exists? True
# ...
# [White] Checking JSON: 44415.json -> Image exists? False
# [White] Removed JSON without image: 44415.json
# [White] Checking JSON: 44464.json -> Image exists? True
# [White] Checking JSON: 44476.json -> Image exists? True
# [White] Checking JSON: 44480.json -> Image exists? True
# [White] Checking JSON: 44484.json -> Image exists? True
# [White] Checking JSON: 445098.json -> Image exists? True
# [White] Checking JSON: 44518.json -> Image exists? True
# [White] Checking JSON: 44519.json -> Image exists? True
# [White] Checking JSON: 44524.json -> Image exists? True
# [White] Checking JSON: 44525.json -> Image exists? True
# [White] Checking JSON: 44526.json -> Image exists? True
# [White] Checking JSON: 44527.json -> Image exists? True
# [White] Checking JSON: 44530.json -> Image exists? True
# [White] Checking JSON: 44531.json -> Image exists? False
# [White] Removed JSON without image: 44531.json
# [White] Checking JSON: 44532.json -> Image exists? False
# [White] Removed JSON without image: 44532.json
# [White] Checking JSON: 44538.json -> Image exists? False
# [White] Removed JSON without image: 44538.json
# [White] Checking JSON: 44566.json -> Image exists? True
# [White] Checking JSON: 445767.json -> Image exists? True
# [White] Checking JSON: 44584.json -> Image exists? True
# [White] Checking JSON: 44592.json -> Image exists? True
# [White] Checking JSON: 44614.json -> Image exists? True
# [White] Checking JSON: 44625.json -> Image exists? True
# [White] Checking JSON: 44634.json -> Image exists? True
# [White] Checking JSON: 44662.json -> Image exists? True
# [White] Checking JSON: 44696.json -> Image exists? True
# [White] Checking JSON: 447060.json -> Image exists? True
# [White] Checking JSON: 44745.json -> Image exists? False
# [White] Removed JSON without image: 44745.json
# [White] Checking JSON: 44778.json -> Image exists? True
# [White] Checking JSON: 44853.json -> Image exists? True
# [White] Checking JSON: 448548.json -> Image exists? True
# [White] Checking JSON: 44857.json -> Image exists? True
# [White] Checking JSON: 448753.json -> Image exists? True
# [White] Checking JSON: 44897.json -> Image exists? True
# [White] Checking JSON: 44911.json -> Image exists? True
# [White] Checking JSON: 44948.json -> Image exists? True
# [White] Checking JSON: 44963.json -> Image exists? True
# [White] Checking JSON: 44967.json -> Image exists? True
# [White] Checking JSON: 44970.json -> Image exists? True
# [White] Checking JSON: 44972.json -> Image exists? True
# [White] Checking JSON: 45008.json -> Image exists? True
# [White] Checking JSON: 45028.json -> Image exists? False
# [White] Removed JSON without image: 45028.json
# [White] Checking JSON: 45051.json -> Image exists? True
# [White] Checking JSON: 45052.json -> Image exists? True
# [White] Checking JSON: 45055.json -> Image exists? True
# [White] Checking JSON: 45092.json -> Image exists? True
# [White] Checking JSON: 45098.json -> Image exists? True
# [White] Checking JSON: 45125.json -> Image exists? True
# [White] Checking JSON: 45183.json -> Image exists? True
# [White] Checking JSON: 45191.json -> Image exists? True
# [White] Checking JSON: 45232.json -> Image exists? False
# [White] Removed JSON without image: 45232.json
# [White] Checking JSON: 45355.json -> Image exists? True
# [White] Checking JSON: 453613.json -> Image exists? False
# [White] Removed JSON without image: 453613.json
# [White] Checking JSON: 45364.json -> Image exists? True
# [White] Checking JSON: 45387.json -> Image exists? True
# [White] Checking JSON: 45403.json -> Image exists? True
# [White] Checking JSON: 45404.json -> Image exists? True
# [White] Checking JSON: 45405.json -> Image exists? True
# [White] Checking JSON: 45424.json -> Image exists? True
# [White] Checking JSON: 45456.json -> Image exists? True
# [White] Checking JSON: 454785.json -> Image exists? True
# [White] Checking JSON: 45499.json -> Image exists? True
# [White] Checking JSON: 45578.json -> Image exists? True
# [White] Checking JSON: 45579.json -> Image exists? True
# [White] Checking JSON: 45581.json -> Image exists? True
# [White] Checking JSON: 45615.json -> Image exists? True
# [White] Checking JSON: 45618.json -> Image exists? True
# [White] Checking JSON: 45733.json -> Image exists? True
# [White] Checking JSON: 45736.json -> Image exists? True
# [White] Checking JSON: 458786.json -> Image exists? True
# [White] Checking JSON: 458851.json -> Image exists? True
# [White] Checking JSON: 45926.json -> Image exists? True
# [White] Checking JSON: 46042.json -> Image exists? True
# [White] Checking JSON: 460493.json -> Image exists? True
# [White] Checking JSON: 46054.json -> Image exists? True
# [White] Checking JSON: 46059.json -> Image exists? True
# [White] Checking JSON: 46087.json -> Image exists? True
# [White] Checking JSON: 461327.json -> Image exists? True
# [White] Checking JSON: 462085.json -> Image exists? True
# [White] Checking JSON: 46295.json -> Image exists? True
# [White] Checking JSON: 46296.json -> Image exists? True
# [White] Checking JSON: 46297.json -> Image exists? True
# [White] Checking JSON: 46315.json -> Image exists? True
# [White] Checking JSON: 46338.json -> Image exists? True
# [White] Checking JSON: 46453.json -> Image exists? True
# [White] Checking JSON: 46461.json -> Image exists? True
# [White] Checking JSON: 46462.json -> Image exists? True
# [White] Checking JSON: 46472.json -> Image exists? True
# [White] Checking JSON: 46475.json -> Image exists? True
# [White] Checking JSON: 46483.json -> Image exists? True
# [White] Checking JSON: 46484.json -> Image exists? True
# [White] Checking JSON: 465146.json -> Image exists? True
# [White] Checking JSON: 465849.json -> Image exists? True
# [White] Checking JSON: 465989.json -> Image exists? True
# [White] Checking JSON: 46819.json -> Image exists? True
# [White] Checking JSON: 469361.json -> Image exists? True
# [White] Checking JSON: 470062.json -> Image exists? True
# [White] Checking JSON: 470070.json -> Image exists? True
# [White] Checking JSON: 471318.json -> Image exists? True
# [White] Checking JSON: 472555.json -> Image exists? True
# [White] Checking JSON: 473702.json -> Image exists? True
# [White] Checking JSON: 474239.json -> Image exists? True
# [White] Checking JSON: 474742.json -> Image exists? True
# [White] Checking JSON: 477869.json -> Image exists? True
# [White] Checking JSON: 477877.json -> Image exists? True
# [White] Checking JSON: 483255.json -> Image exists? True
# [White] Checking JSON: 484469.json -> Image exists? False
# [White] Removed JSON without image: 484469.json
# [White] Checking JSON: 485086.json -> Image exists? True
# [White] Checking JSON: 487496.json -> Image exists? True
# [White] Checking JSON: 489179.json -> Image exists? True
# [White] Checking JSON: 492116.json -> Image exists? True
# [White] Checking JSON: 495507.json -> Image exists? True
# [White] Checking JSON: 499509.json -> Image exists? True
# [White] Checking JSON: 499707.json -> Image exists? True
# [White] Checking JSON: 507475.json -> Image exists? True
# [White] Checking JSON: 512277.json -> Image exists? True
# [White] Checking JSON: 516625.json -> Image exists? True
# [White] Checking JSON: 520668.json -> Image exists? True
# [White] Checking JSON: 524314.json -> Image exists? True
# [White] Checking JSON: 526251.json -> Image exists? True
# [White] Checking JSON: 530261.json -> Image exists? True
# [White] Checking JSON: 531780.json -> Image exists? True
# [White] Checking JSON: 5322.json -> Image exists? True
# [White] Checking JSON: 532341.json -> Image exists? True
# [White] Checking JSON: 535682.json -> Image exists? True
# [White] Checking JSON: 536169.json -> Image exists? True
# [White] Checking JSON: 53868.json -> Image exists? True
# [White] Checking JSON: 542597.json -> Image exists? True
# [White] Checking JSON: 545871.json -> Image exists? True
# [White] Checking JSON: 546812.json -> Image exists? True
# [White] Checking JSON: 55533.json -> Image exists? True
# [White] Checking JSON: 556134.json -> Image exists? True
# [White] Checking JSON: 556217.json -> Image exists? True
# [White] Checking JSON: 556597.json -> Image exists? True
# [White] Checking JSON: 556746.json -> Image exists? True
# [White] Checking JSON: 560284.json -> Image exists? True
# [White] Checking JSON: 561381.json -> Image exists? True
# [White] Checking JSON: 562058.json -> Image exists? True
# [White] Checking JSON: 562173.json -> Image exists? True
# [White] Checking JSON: 563130.json -> Image exists? True
# [White] Checking JSON: 564674.json -> Image exists? True
# [White] Checking JSON: 569087.json -> Image exists? True
# [White] Checking JSON: 570457.json -> Image exists? True
# [White] Checking JSON: 570770.json -> Image exists? True
# [White] Checking JSON: 573683.json -> Image exists? True
# [White] Checking JSON: 574533.json -> Image exists? True
# [White] Checking JSON: 576470.json -> Image exists? True
# [White] Checking JSON: 578641.json -> Image exists? True
# [White] Checking JSON: 580183.json -> Image exists? True
# [White] Checking JSON: 580324.json -> Image exists? True
# [White] Checking JSON: 58677.json -> Image exists? True
# [White] Checking JSON: 589010.json -> Image exists? True
# [White] Checking JSON: 589051.json -> Image exists? True
# [White] Checking JSON: 589101.json -> Image exists? True
# [White] Checking JSON: 589432.json -> Image exists? True
# [White] Checking JSON: 592691.json -> Image exists? True
# [White] Checking JSON: 610758.json -> Image exists? True
# [White] Checking JSON: 610972.json -> Image exists? True
# [White] Checking JSON: 611475.json -> Image exists? True
# [White] Checking JSON: 614826.json -> Image exists? True
# [White] Checking JSON: 618108.json -> Image exists? True
# [White] Checking JSON: 618231.json -> Image exists? True
# [White] Checking JSON: 619452.json -> Image exists? True
# [White] Checking JSON: 620054.json -> Image exists? True
# [White] Checking JSON: 620492.json -> Image exists? True
# [White] Checking JSON: 620583.json -> Image exists? True
# [White] Checking JSON: 620617.json -> Image exists? True
# [White] Checking JSON: 620724.json -> Image exists? True
# [White] Checking JSON: 620773.json -> Image exists? True
# [White] Checking JSON: 621219.json -> Image exists? True
# [White] Checking JSON: 621821.json -> Image exists? True
# [White] Checking JSON: 621888.json -> Image exists? True
# [White] Checking JSON: 623322.json -> Image exists? True
# [White] Checking JSON: 627802.json -> Image exists? True
# [White] Checking JSON: 628065.json -> Image exists? True
# [White] Checking JSON: 628404.json -> Image exists? True
# [White] Checking JSON: 628578.json -> Image exists? False
# [White] Removed JSON without image: 628578.json
# [White] Checking JSON: 628586.json -> Image exists? False
# [White] Removed JSON without image: 628586.json
# [White] Checking JSON: 629997.json -> Image exists? True
# [White] Checking JSON: 631648.json -> Image exists? True
# [White] Checking JSON: 63313.json -> Image exists? True
# [White] Checking JSON: 633578.json -> Image exists? True
# [White] Checking JSON: 634402.json -> Image exists? True
# [White] Checking JSON: 634410.json -> Image exists? True
# [White] Checking JSON: 638106.json -> Image exists? False
# [White] Removed JSON without image: 638106.json
# [White] Checking JSON: 63826.json -> Image exists? True
# [White] Checking JSON: 641944.json -> Image exists? True
# [White] Checking JSON: 643361.json -> Image exists? True
# [White] Checking JSON: 646067.json -> Image exists? True
# [White] Checking JSON: 646497.json -> Image exists? True
# [White] Checking JSON: 646802.json -> Image exists? True
# [White] Checking JSON: 648436.json -> Image exists? True
# [White] Checking JSON: 648717.json -> Image exists? True
# [White] Checking JSON: 648840.json -> Image exists? True
# [White] Checking JSON: 65086.json -> Image exists? True
# [White] Checking JSON: 65367.json -> Image exists? True
# [White] Checking JSON: 660704.json -> Image exists? True
# [White] Checking JSON: 66266.json -> Image exists? True
# [White] Checking JSON: 666560.json -> Image exists? True
# [White] Checking JSON: 667089.json -> Image exists? True
# [White] Checking JSON: 667097.json -> Image exists? True
# [White] Checking JSON: 668269.json -> Image exists? True
# [White] Checking JSON: 668947.json -> Image exists? True
# [White] Checking JSON: 668954.json -> Image exists? True
# [White] Checking JSON: 669085.json -> Image exists? True
# [White] Checking JSON: 669200.json -> Image exists? True
# [White] Checking JSON: 669226.json -> Image exists? True
# [White] Checking JSON: 669374.json -> Image exists? True
# [White] Checking JSON: 669473.json -> Image exists? True
# [White] Checking JSON: 669531.json -> Image exists? True
# [White] Checking JSON: 672394.json -> Image exists? True
# [White] Checking JSON: 677153.json -> Image exists? True
# [White] Checking JSON: 677450.json -> Image exists? True
# [White] Checking JSON: 68015.json -> Image exists? True
# [White] Checking JSON: 68254.json -> Image exists? True
# [White] Checking JSON: 68536.json -> Image exists? True
# [White] Checking JSON: 686675.json -> Image exists? True
# [White] Checking JSON: 687558.json -> Image exists? True
# [White] Checking JSON: 68817.json -> Image exists? True
# [White] Checking JSON: 69336.json -> Image exists? True
# [White] Checking JSON: 697102.json -> Image exists? False
# [White] Removed JSON without image: 697102.json
# [White] Checking JSON: 699058.json -> Image exists? True
# [White] Checking JSON: 707158.json -> Image exists? True
# [White] Checking JSON: 708073.json -> Image exists? True
# [White] Checking JSON: 71233.json -> Image exists? True
# [White] Checking JSON: 729.json -> Image exists? True
# [White] Checking JSON: 73148.json -> Image exists? True
# [White] Checking JSON: 73163.json -> Image exists? True
# [White] Checking JSON: 73205.json -> Image exists? True
# [White] Checking JSON: 734798.json -> Image exists? True
# [White] Checking JSON: 75663.json -> Image exists? True
# [White] Checking JSON: 77990.json -> Image exists? True
# [White] Checking JSON: 78493.json -> Image exists? True
# [White] Checking JSON: 79046.json -> Image exists? True
# [White] Checking JSON: 79129.json -> Image exists? True
# [White] Checking JSON: 80234.json -> Image exists? True
# [White] Checking JSON: 80788.json -> Image exists? True
# [White] Checking JSON: 8094.json -> Image exists? True
# [White] Checking JSON: 81653.json -> Image exists? True
# [White] Checking JSON: 82073.json -> Image exists? True
# [White] Checking JSON: 82305.json -> Image exists? True
# [White] Checking JSON: 82636.json -> Image exists? True
# [White] Checking JSON: 83253.json -> Image exists? True
# [White] Checking JSON: 83790.json -> Image exists? True
# [White] Checking JSON: 85456.json -> Image exists? True
# [White] Checking JSON: 86199.json -> Image exists? True
# [White] Checking JSON: 88955.json -> Image exists? True
# [White] Checking JSON: 89011.json -> Image exists? True
# [White] Checking JSON: 89029.json -> Image exists? True
# [White] Checking JSON: 89037.json -> Image exists? True
# [White] Checking JSON: 89995.json -> Image exists? True
# [White] Checking JSON: 9142.json -> Image exists? True
# [White] Checking JSON: 919514.json -> Image exists? True
# [White] Checking JSON: 92114.json -> Image exists? True
# [White] Checking JSON: 924555.json -> Image exists? True
# [White] Checking JSON: 933077.json -> Image exists? True
# [White] Checking JSON: 944298.json -> Image exists? True
# [White] Checking JSON: 948158.json -> Image exists? True
# [White] Checking JSON: 951319.json -> Image exists? True
# [White] Checking JSON: 958801.json -> Image exists? True
# [White] Checking JSON: 959031.json -> Image exists? True
# [White] Checking JSON: 974527.json -> Image exists? True
# [White] Checking JSON: 974717.json -> Image exists? True
# [White] Checking JSON: 983395.json -> Image exists? True
# [White] Checking JSON: 984864.json -> Image exists? True
# [White] Checking JSON: 991950.json -> Image exists? True
# [White] Checking JSON: 99218.json -> Image exists? True
# [White] Checking JSON: 99309.json -> Image exists? True
# [White] Checking JSON: 994012.json -> Image exists? True
# [White] Checking JSON: 994939.json -> Image exists? True
# [White] Checking JSON: 998583.json -> Image exists? True
# [White] Checking JSON: 999979.json -> Image exists? True

# %%
base_dir = r"C:\Users\syune\OneDrive\Desktop\Wine_Data/Data"

# get all folder names inside Data
folders = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]

# build json directories
json_dirs = [os.path.join(base_dir, f, "labels") for f in folders]

# list to store records
records = []

# loop through json directories
for folder, json_dir in zip(folders, json_dirs):
    if os.path.exists(json_dir):  # check if labels folder exists
        for json_file in os.listdir(json_dir):
            if json_file.endswith(".json"):
                json_path = os.path.join(json_dir, json_file)

                try:
                    with open(json_path, "r", encoding="utf-8") as f:
                        data = json.load(f)  # parse json content

                    # extract fields from JSON
                    name = data.get("Name", None)
                    brand = data.get("Brand", None)

                    # assign type from folder name instead of JSON
                    wine_type = folder

                    # handle region → split by comma and take last part (country)
                    region = data.get("Region", None)
                    country = None
                    if region and "," in region:
                        country = region.split(",")[-1].strip()
                    elif region:  # if no comma, take full string
                        country = region.strip()

                    # build image path
                    image_dir = os.path.join(base_dir, folder, "images")
                    image_filename = os.path.splitext(json_file)[0]  # remove .json
                    # look for common image extensions
                    for ext in [".jpg", ".jpeg", ".png"]:
                        image_path = os.path.join(image_dir, image_filename + ext)
                        if os.path.exists(image_path):
                            break
                    else:
                        image_path = None  # if no matching image found

                    # store each file's data + paths
                    records.append({
                        "image_path": image_path,
                        "file_name": json_file,
                        "Name": name,
                        "Brand": brand,
                        "Type": wine_type,  # <-- folder name
                        "Country": country
                    })
                except Exception as e:
                    print(f"Error reading {json_path}: {e}")

# convert to DataFrame
df_json = pd.DataFrame(records)

df_json.head()
# Out:
#                                           image_path    file_name  \
# 0  C:\Users\syune\OneDrive\Desktop\Wine_Data/Data...  100503.json
# 1                                               None  106583.json
# 2  C:\Users\syune\OneDrive\Desktop\Wine_Data/Data...  111294.json
# 3  C:\Users\syune\OneDrive\Desktop\Wine_Data/Data...   12619.json
# 4  C:\Users\syune\OneDrive\Desktop\Wine_Data/Data...  135798.json
#
#                                               Name  \
# 0                    Bollinger Brut Rosé Champagne
# 1     Charles Ellner Séduction Brut Champagne 2007
# 2           Moët & Chandon Brut Imperial Champagne
# 3  Vilmart et Cie Grande Réserve 1er Cru Champagne
# 4   Perrier-Jouët Belle Epoque Brut Champagne 2016
#
#                          Brand       Type Country
# 0                    Bollinger  Champagne  France
# 1                Charles Ellne  Champagne  France
# 2               Moet & Chandon  Champagne  France
# 3  Vintages Front Line Release  Champagne  France
# 4   Vintages Classic Catalogue  Champagne  France

# %%
df_json.to_excel(r'C:\Users\syune\OneDrive\Desktop\Wine_Data/wine_data.xlsx')
